# %%
import requests

# %%
markers_url = 'https://ejatlas.org/data/markers-en.json'

# %%
headers = {
'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:79.0) Gecko/20100101 Firefox/79.0',
'Referer': 'https://ejatlas.org/',    
'DNT': '1',
'X-Requested-With': 'XMLHttpRequest',
'Accept': 'application/json, text/javascript, */*; q=0.01',
    }

# %%
resp = requests.get(markers_url, headers=headers)

# %%
resp.json()
# Out:
# [{'o': 9.19,
#   'a': 48.79,
#   'i': 3,
#   'c': 7,
#   'r': 3,
#   's': 4,
#   'p': 4,
#   'l': 'en-es-it'},
#  {'o': -0.1, 'a': 51.48, 'i': 4, 'c': 7, 'r': 3, 's': 3, 'p': 3, 'l': 'en'},
#  {'o': 7.24, 'a': 43.71, 'i': 5, 'c': 7, 'r': 3, 's': 3, 'p': 4, 'l': 'en'},
#  {'o': 11.28, 'a': 54.57, 'i': 6, 'c': 7, 'r': 1, 's': 3, 'p': 3, 'l': 'en'},
#  {'o': -0.2, 'a': 42.79, 'i': 7, 'c': 7, 'r': 3, 's': 3, 'p': 2, 'l': 'en'},
#  {'o': 4.98, 'a': 45.76, 'i': 8, 'c': 8, 'r': 3, 's': 3, 'p': 2, 'l': 'en-fr'},
#  {'o': -3.98, 'a': 38.86, 'i': 9, 'c': 7, 'r': 2, 's': 4, 'p': 6, 'l': 'en'},
#  {'o': -2.27, 'a': 43.06, 'i': 11, 'c': 7, 'r': 3, 's': 4, 'p': 4, 'l': 'en'},
#  {'o': -1.75, 'a': 43.36, 'i': 12, 'c': 7, 'r': 3, 's': 3, 'p': 2, 'l': 'en'},
#  {'o': 5.36,
#   'a': 48.51,
#   'i': 13,
#   'c': 1,
#   'r': 3,
#   's': 4,
#   'p': 2,
#   'l': 'en-fr'},
#  {'o': 5.75,
#   'a': 43.68,
#   'i': 14,
#   'c': 1,
#   'r': 3,
#   's': 3,
#   'p': 3,
#   'l': 'en-fr'},
#  {'o': -68.64,
# ...

# %%
requests.get('https://ejatlas.org/info/2270')
# Out:
# <Response [500]>

# %%
headers = {
'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:79.0) Gecko/20100101 Firefox/79.0',
'Accept': '*/*',
'Accept-Language': 'es-ES,es;q=0.8,en-US;q=0.5,en;q=0.3',
'X-Requested-With': 'XMLHttpRequest',
'Connection': 'keep-alive',
'Referer': 'https://ejatlas.org/',
'Cookie': '__cfduid=d7e34593131a54fa76a7e5bdb171df61d1598541779; rack.session=BAh7CEkiD3Nlc3Npb25faWQGOgZFVEkiRTgzNmZkZDJjY2NiYTIxZjg2ODE5%0AMWZkZTI1ODlhZDBkYjBmM2U4ZTVlMDI3NTNlNDZjOTAwNGY3M2NhZWMzNzAG%0AOwBGSSIJY3NyZgY7AEZJIjFOZ2dNWmFDYk1Tbk54SE96K09rd0FSM1FzNURJ%0AbWx5WW9YQVVXY1dsSjFjPQY7AEZJIg10cmFja2luZwY7AEZ7BkkiFEhUVFBf%0AVVNFUl9BR0VOVAY7AFRJIi01MjUwN2YyNzNkNDFhMmQxZTg4MGI3NTc5ZTE4%0AOTUyNzJhOWRhNGY3BjsARg%3D%3D%0A--a23dd5c7f62cb748aa907909861ce4fd6123df26; __utma=231819979.1160077120.1598541781.1598541781.1598541781.1; __utmb=231819979.10.10.1598541781; __utmc=231819979; __utmz=231819979.1598541781.1.1.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided); __utmt=1',
'TE': 'Trailers'
    }

# %%
resp = requests.get('https://ejatlas.org/info/2270', headers=headers)

# %%
resp.text
# Out:
# "<h4 class='maplink'><a href='/conflict/fuleni-mine'>Fuleni blockade and leave the coal in the hole campaign, South Africa</a></h4><p>The Fuleni proposed open cast coal mine in Kwa Zulu Natal stands very near the border of the very valuable Hluhluwe-iMfolozi Wilderness area. There is confluence of protests from conservationists and local people. <a href='/conflict/fuleni-mine'><em>See more</em></a></p><table style='padding:24px 16px;'><tr><td style='width:42px'><div class='map-icon c_2' style='margin:0 !important;cursor:default'></div><td><strong>Mineral Ores and Building Materials Extraction</strong></td></tr></table>"
